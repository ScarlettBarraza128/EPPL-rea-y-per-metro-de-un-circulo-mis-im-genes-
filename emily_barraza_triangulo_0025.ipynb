# %% [markdown]
# <a href="https://colab.research.google.com/github/ScarlettBarraza128/EPPL-rea-y-per-metro-de-un-circulo-mis-im-genes-/blob/main/emily_barraza_triangulo_0025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Emily Barraza NL = 7 Fecha/25/marzo/2026 ❤
#
#
# ---
# # calcular area de un triangulo
#
#
# ---
# ![Logo de Markdown](https://raw.githubusercontent.com/ScarlettBarraza128/EPPL-rea-y-per-metro-de-un-circulo-mis-im-genes-/refs/heads/main/AreaTriangulo.webp)
#
#
#
# ---
# # formula para calcular el area
# $ A = b * h/ 2$
#
#
# ---
#
# # Datos de entrada
# $h$ ?
# $b$ ?
#
#
#
# ---
# # Diagrama de flujo en LuciChart
# ![Logo de Markdown](https://raw.githubusercontent.com/ScarlettBarraza128/EPPL-rea-y-per-metro-de-un-circulo-mis-im-genes-/refs/heads/main/DF%20%C3%81reaPer%C3%ADmetroCirculo.png)

# %%
# calcular area de un triangulo
# variables b, h , A
# formulas A = b * h / 2
# calcular el valor de b
# calcular el valor de h
print("calcular el area de un triangulo rectangulo")
b = float(input("ingrese el valor de la base: "))
h = float(input("ingrese el valor de la altura: "))
A = b * h / 2
print("el area del triangulo es: ", A)
print("Emily Barraza NL = 7")
# Out:
# calcular el area de un triangulo rectangulo
# ingrese el valor de la base: 10
# ingrese el valor de la altura: 6
# el area del triangulo es:  30.0
# Emily Barraza NL = 7

# %% [markdown]
# # Relación entre código y DF Tldraw
# ---
# ![Logo de Markdown](https://raw.githubusercontent.com/ScarlettBarraza128/EPPL-rea-y-per-metro-de-un-circulo-mis-im-genes-/refs/heads/main/tldraw%20DF%20y%20codigo%20triangulo.png)
